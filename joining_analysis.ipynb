# %%
import pandas as pd
import numpy as np
import nltk
import time
import re
import time
import math
import seaborn as sb

# %%
final_db = pd.read_csv("gamedata_final.csv", index_col=0)

# %%
final_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21270 entries, 0 to 39679
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   steam_appid                      21270 non-null  float64
#  1   name                             21270 non-null  object
#  2   about_the_game                   21229 non-null  object
#  3   is_free                          21270 non-null  bool
#  4   detailed_description             21236 non-null  object
#  5   short_description                21256 non-null  object
#  6   supported_languages              21270 non-null  object
#  7   pc_requirements_minimum          21270 non-null  object
#  8   pc_requirements_recommended      21270 non-null  object
#  9   developers                       21270 non-null  object
#  10  publishers                       21270 non-null  object
#  11  price_overview_initial           21270 non-null  float64
# ...

# %%
final_db
# Out:
#        steam_appid                           name  \
# 0           1313.0                      SiN: Gold
# 1         212740.0                           TERA
# 58       1084790.0                        WarPlan
# 60       1090630.0       Granblue Fantasy: Versus
# 81       1149940.0  Lock 'n Load Tactical Digital
# ...            ...                            ...
# 39671     726250.0                     Unknightly
# 39674     726320.0                    Girl Blonde
# 39676     726340.0             Alchemist's Castle
# 39678     726390.0               Scream Collector
# 39679     726430.0                Creeping Terror
#
#                                           about_the_game  is_free  \
# 0      When the CEO of SinTEK Industries begins injec...    False
# 1      TERA – Fantasy, MMORPG, Strategy and Skill!Get...     True
# 58     WarPlan is an incredibly accurate World War II...    False
# 60      Granblue Fantasy has soared into the hearts o...    False
# ...

# %%
cleaned['categories'].str.get_dummies(sep=',')
# Out:
#         Captions available   Co-op   Commentary available  \
# 0                        0       0                      0
# 1                        0       1                      0
# 58                       0       0                      0
# 60                       0       1                      0
# 81                       0       0                      0
# ...                    ...     ...                    ...
# 39671                    0       0                      0
# 39674                    0       0                      0
# 39676                    0       0                      0
# 39678                    0       0                      0
# 39679                    0       0                      0
#
#         Cross-Platform Multiplayer   Full controller support  \
# 0                                0                         0
# 1                                0                         0
# 58                               0                         0
# ...
