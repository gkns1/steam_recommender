# %%
import pandas as pd
import numpy as np
import nltk
import time
import re
import time
import math

# %%
df_main = pd.read_csv("dataframe.csv",index_col = "steam_appid")

# %%
df_sup = pd.read_csv("dataframe_supplement.csv",index_col = "steam_appid")

# %%
df_main.shape
# Out:
# (39533, 24)

# %%
df_sup.shape
# Out:
# (39845, 7)

# %%
df_joined = pd.merge(df_main,df_sup, on="steam_appid")

# %%
df_joined.shape
# Out:
# (39462, 31)

# %%
df_joined.head()
# Out:
#              Unnamed: 0_x                                           name  \
# steam_appid
# 722190                  0                                         EEP 14
# 722190              39385                                         EEP 14
# 722200                  1  EEP TSM Gotthardbahn Nordrampe Modul Erstfeld
# 722200              39386  EEP TSM Gotthardbahn Nordrampe Modul Erstfeld
# 722210                  2                                     Smart Cube
#
#                                                 about_the_game  is_free  \
# steam_appid
# 722190       EEP 14 eisenbahn.exe Professional basicRealist...    False
# 722190       EEP 14 eisenbahn.exe Professional basicRealist...    False
# 722200        Start your mission at the Gotthard Railway No...    False
# 722200        Start your mission at the Gotthard Railway No...    False
# 722210       Smart Cube is a first-person puzzle game where...    False
#
#                                           detailed_description  \
# ...
